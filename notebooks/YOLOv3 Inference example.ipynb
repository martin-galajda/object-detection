# %% [markdown]
# # Example for inference with YOLOv3 model
#
# First, let's construct the model

# %%
# %matplotlib inline
from models.yolov3.object_detector import ObjectDetector as YOLOv3ObjectDetector

    
yolov3_detector = YOLOv3ObjectDetector()
# Out:
# Using TensorFlow backend.
# /Users/martingalajda/School/DIPLOMA-THESIS/object-detection/venv/lib/python3.6/site-packages/keras/engine/saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
# Took 27.919618129730225 seconds to construct network.

# %% [markdown]
# Now, let's showcase inference on simple image containing horse

# %%
PATH_TO_TEST_FILE = '../resources/horse.jpeg'
from models.utils.visualize import draw_bounding_boxes_on_pil_image
from utils.image import load_pil_image_from_file
import matplotlib.pyplot as plt


def test():
    orig_img_pil, img_np = load_pil_image_from_file(PATH_TO_TEST_FILE)
    bounding_boxes = yolov3_detector.infer_bounding_boxes_on_target_path(PATH_TO_TEST_FILE)
    
    draw_bounding_boxes_on_pil_image(bounding_boxes, orig_img_pil)
    
    plt.imshow(orig_img_pil)
    
test()
# Out:
# Took 22.02541494369507 seconds to run prediction in tf session.
